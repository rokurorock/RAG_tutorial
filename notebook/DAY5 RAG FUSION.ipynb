# %% [markdown]
# # RAG FUSION
# RAG FUSIONとは元の問い合わせから派生となるクエリを複数生成し、各クエリの検索結果をReciprocal Rank Fusionというアルゴリズムを用いてRe-ranking(順序付け)し、関連度の高いものを抽出する手法です

# %% [markdown]
# ##  下準備

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter,RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain

#Document load
loader = DirectoryLoader("../datasets/company_documents_dataset_1/", glob="**/*.txt",recursive=True)
raw_docs = loader.load()

# Document split
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]
markdown_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on, 
    return_each_line=False,
    strip_headers = False 
)
docs = []
for raw_doc in raw_docs:
    source = raw_doc.metadata["source"]
    spilited_docs = markdown_splitter.split_text(raw_doc.page_content)
    for doc in spilited_docs:
        doc.metadata["source"] = source#metadataにsourceを加える
    docs = docs + spilited_docs
markdown_splited_docs = docs
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 800,chunk_overlap=50)
docs = text_splitter.split_documents(docs)

# Embd
vectorstore = Chroma.from_documents(persist_directory="./vecstore/index", documents=docs, embedding=OpenAIEmbeddings())

#llm
llm = ChatOpenAI(model_name="gpt-3.5-turbo",temperature=0)

# %% [markdown]
# ## 複数のqueryを作成するpromptの実装

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks.tracers import ConsoleCallbackHandler

template = """AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。
これらの代替質問を改行で区切って提供してください。オリジナルの質問: {question}"""
prompt_perspectives = ChatPromptTemplate.from_template(template)

generate_queries = (
    prompt_perspectives 
    | ChatOpenAI(temperature=0) 
    | StrOutputParser() 
    | (lambda x: x.split("\n"))#改行コードごとにsplitで区切ってリストにする
)

#動作確認
question = "社長の略歴を教えて"
handler = ConsoleCallbackHandler()
result = generate_queries.invoke({"question":question},{"callbacks":[handler]})
print("結果:",result)
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "社長の略歴を教えて"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "question": "社長の略歴を教えて"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 社長の略歴を教えて",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 社長の略歴を教えて"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] [2.57s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "社長の経歴を教えてください。\n社長の経歴について教えてください。\n社長の経歴はどうなっていますか？\n社長の経歴に関する情報を教えてください。\n社長の経歴について詳細を教えてください。",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "社長の経歴を教えてください。\n社長の経歴について教えてください。\n社長の経歴はどうなっていますか？\n社長の経歴に関する情報を教えてください。\n社長の経歴について詳細を教えてください。",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 92,
#       "prompt_tokens": 209,
#       "total_tokens": 301
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": "fp_69829325d0"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "社長の経歴を教えてください。\n社長の経歴について教えてください。\n社長の経歴はどうなっていますか？\n社長の経歴に関する情報を教えてください。\n社長の経歴について詳細を教えてください。"
# }
# [chain/start] [1:chain:RunnableSequence > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": "社長の経歴を教えてください。\n社長の経歴について教えてください。\n社長の経歴はどうなっていますか？\n社長の経歴に関する情報を教えてください。\n社長の経歴について詳細を教えてください。"
# }
# [chain/end] [1:chain:RunnableSequence > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": [
#     "社長の経歴を教えてください。",
#     "社長の経歴について教えてください。",
#     "社長の経歴はどうなっていますか？",
#     "社長の経歴に関する情報を教えてください。",
#     "社長の経歴について詳細を教えてください。"
#   ]
# }
# [chain/end] [1:chain:RunnableSequence] [2.57s] Exiting Chain run with output:
# {
#   "output": [
#     "社長の経歴を教えてください。",
#     "社長の経歴について教えてください。",
#     "社長の経歴はどうなっていますか？",
#     "社長の経歴に関する情報を教えてください。",
#     "社長の経歴について詳細を教えてください。"
#   ]
# }
# 結果: ['社長の経歴を教えてください。', '社長の経歴について教えてください。', '社長の経歴はどうなっていますか？', '社長の経歴に関する情報を教えてください。', '社長の経歴について詳細を教えてください。']

# %% [markdown]
# ## Reciprocal Rank Fusion関数の実装とretreaval chainの作成
#
# 参考
# https://qiita.com/isanakamishiro2/items/f4387443b86723eecf36

# %%
from langchain.load import dumps, loads
def reciprocal_rank_fusion(results: list[list], k=10):
    fused_scores = {}
    for docs in results:
        # Assumes the docs are returned in sorted order of relevance
        for rank, doc in enumerate(docs):
            doc_str = dumps(doc)
            if doc_str not in fused_scores:
                fused_scores[doc_str] = 0
            fused_scores[doc_str] += 1 / (rank + k)

    reranked_results = [
        (loads(doc), score)
        for doc, score in sorted(fused_scores.items(), key=lambda x: x[1], reverse=True)
    ]
    return reranked_results


# retriever
retriever = vectorstore.as_retriever(search_kwargs={"k": 10})

question = "残業手当はいくら？"
retrieval_chain = generate_queries | retriever.map() | reciprocal_rank_fusion
docs = retrieval_chain.invoke({"question": question},{"callbacks":[handler]})
print("-"*150)
for doc in docs:
    print(doc)
    print("")
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 残業手当はいくら？",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 残業手当はいくら？"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] [2.87s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業手当の支給条件は何ですか？\n4. 残業手当は時間給に基づいていますか？\n5. 残業手当の支払いは週ごとに行われますか？",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業手当の支給条件は何ですか？\n4. 残業手当は時間給に基づいていますか？\n5. 残業手当の支払いは週ごとに行われますか？",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 110,
#       "prompt_tokens": 207,
#       "total_tokens": 317
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": "fp_69829325d0"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業手当の支給条件は何ですか？\n4. 残業手当は時間給に基づいていますか？\n5. 残業手当の支払いは週ごとに行われますか？"
# }
# [chain/start] [1:chain:RunnableSequence > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業手当の支給条件は何ですか？\n4. 残業手当は時間給に基づいていますか？\n5. 残業手当の支払いは週ごとに行われますか？"
# }
# [chain/end] [1:chain:RunnableSequence > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 残業手当の金額はどれくらいですか？",
#     "2. 残業手当はどのように計算されますか？",
#     "3. 残業手当の支給条件は何ですか？",
#     "4. 残業手当は時間給に基づいていますか？",
#     "5. 残業手当の支払いは週ごとに行われますか？"
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 6:chain:RunnableEach<VectorStoreRetriever>] Entering Chain run with input:
# {
#   "input": [
#     "1. 残業手当の金額はどれくらいですか？",
#     "2. 残業手当はどのように計算されますか？",
#     "3. 残業手当の支給条件は何ですか？",
#     "4. 残業手当は時間給に基づいていますか？",
#     "5. 残業手当の支払いは週ごとに行われますか？"
#   ]
# }
# [chain/end] [1:chain:RunnableSequence > 6:chain:RunnableEach<VectorStoreRetriever>] s] Exiting Chain run with output:
# {
#   "output": [
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ]
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 12:chain:reciprocal_rank_fusion] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 12:chain:reciprocal_rank_fusion] s] Exiting Chain run with output:
# {
#   "output": [
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "１. 給与は、毎月２０日に締切り毎月末日に支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "２. 役職手当は支給対象となった翌月分から支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円",
#           "metadata": {
#             "Header 1": "第７条（休日振替手当）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ]
#   ]
# }
# [chain/end] [1:chain:RunnableSequence] [3.52s] Exiting Chain run with output:
# [outputs]
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# (Document(page_content='# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円', metadata={'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256)
#
# (Document(page_content='## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256)
#
# (Document(page_content='# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当', metadata={'Header 1': '第２条（給与の形態）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256)
#
# (Document(page_content='# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数', metadata={'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '時間外手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256)
#
# (Document(page_content='# 第８条（給与の計算期間・支払日）  \n## １. 給与は、毎月２０日に締切り毎月末日に支払います。  \nただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '１. 給与は、毎月２０日に締切り毎月末日に支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256)
#
# (Document(page_content='## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。', metadata={'Header 1': '第８章 退職金', 'Header 2': '（退職金の額）', 'Header 3': '第２９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}), 0.2961773305813553)
#
# (Document(page_content='## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '３. 欠勤の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)
#
# (Document(page_content='## ２. 役職手当は支給対象となった翌月分から支払います。  \nただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。', metadata={'Header 1': '第４条（役職手当）', 'Header 2': '２. 役職手当は支給対象となった翌月分から支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)
#
# (Document(page_content='## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。  \nなお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。  \n(基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)
#
# (Document(page_content='# 第７条（休日振替手当）  \n休日の振替を行った場合は１回につき次の手当を支給します。  \n１回：1,000円', metadata={'Header 1': '第７条（休日振替手当）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)

# %% [markdown]
# # Chain

# %%
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter

# RAG
rag_template = """Answer the following question based on this context:

{context}

Question: {question}
"""

rag_prompt = ChatPromptTemplate.from_template(rag_template)

rag_chain = (
    {"context": retrieval_chain, 
     "question": itemgetter("question")} 
    | rag_prompt
    | llm
    | StrOutputParser()
)
handler = ConsoleCallbackHandler()
rag_chain.invoke({"question":question},{"callbacks":[handler]})
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question>] Entering Chain run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 3:chain:RunnableLambda] Entering Chain run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 3:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "残業手当はいくら？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "question": "残業手当はいくら？"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 残業手当はいくら？",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 6:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: AI言語モデルアシスタントとして、与えられたユーザーの質問から関連するドキュメントをベクトルデータベースから検索するために、その質問の異なる5つのバージョンを生成することがあなたの任務です。質問に対する複数の視点を生成することで、距離ベースの類似性検索のいくつかの制限を克服するのをユーザーに助けます。\nこれらの代替質問を改行で区切って提供してください。オリジナルの質問: 残業手当はいくら？"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 6:llm:ChatOpenAI] [2.84s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業をした場合、支給される手当はありますか？\n4. 残業手当は時間給に加算されるのでしょうか？\n5. 残業手当の支給条件は何ですか？",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業をした場合、支給される手当はありますか？\n4. 残業手当は時間給に加算されるのでしょうか？\n5. 残業手当の支給条件は何ですか？",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 112,
#       "prompt_tokens": 207,
#       "total_tokens": 319
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": "fp_69829325d0"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 7:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 7:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業をした場合、支給される手当はありますか？\n4. 残業手当は時間給に加算されるのでしょうか？\n5. 残業手当の支給条件は何ですか？"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 8:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": "1. 残業手当の金額はどれくらいですか？\n2. 残業手当はどのように計算されますか？\n3. 残業をした場合、支給される手当はありますか？\n4. 残業手当は時間給に加算されるのでしょうか？\n5. 残業手当の支給条件は何ですか？"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 8:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": [
#     "1. 残業手当の金額はどれくらいですか？",
#     "2. 残業手当はどのように計算されますか？",
#     "3. 残業をした場合、支給される手当はありますか？",
#     "4. 残業手当は時間給に加算されるのでしょうか？",
#     "5. 残業手当の支給条件は何ですか？"
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 9:chain:RunnableEach<VectorStoreRetriever>] Entering Chain run with input:
# {
#   "input": [
#     "1. 残業手当の金額はどれくらいですか？",
#     "2. 残業手当はどのように計算されますか？",
#     "3. 残業をした場合、支給される手当はありますか？",
#     "4. 残業手当は時間給に加算されるのでしょうか？",
#     "5. 残業手当の支給条件は何ですか？"
#   ]
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 9:chain:RunnableEach<VectorStoreRetriever>] s] Exiting Chain run with output:
# {
#   "output": [
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       }
#     ]
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 15:chain:reciprocal_rank_fusion] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence > 15:chain:reciprocal_rank_fusion] s] Exiting Chain run with output:
# {
#   "output": [
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第２条（給与の形態）  \n給与の形態は次のとおりです。  \n基本給  \n役職手当  \n通勤手当  \n時間外労働手当・休日手当・深夜手当  \n休日振替手当",
#           "metadata": {
#             "Header 1": "第２条（給与の形態）",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.718771403175428
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円",
#           "metadata": {
#             "Header 1": "第４条（役職手当）",
#             "Header 2": "１. 役職手当は、次の金額とします。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第６条（時間外手当・休日手当・深夜手当）  \n## 時間外手当  \n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数",
#           "metadata": {
#             "Header 1": "第６条（時間外手当・休日手当・深夜手当）",
#             "Header 2": "時間外手当",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.42259407259407256
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## （退職金の額）  \n### 第２９条  \n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。",
#           "metadata": {
#             "Header 1": "第８章 退職金",
#             "Header 2": "（退職金の額）",
#             "Header 3": "第２９条",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ３. 欠勤の場合は、次の計算により減額します。  \nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "３. 欠勤の場合は、次の計算により減額します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#           "metadata": {
#             "Header 1": "第８条（給与の計算期間・支払日）",
#             "Header 2": "５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ],
#     [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "document",
#           "Document"
#         ],
#         "kwargs": {
#           "page_content": "# 第５条（通勤手当）  \n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#           "metadata": {
#             "Header 1": "第５条（通勤手当）",
#             "Header 2": "１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。",
#             "source": "../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt"
#           }
#         }
#       },
#       0.2961773305813553
#     ]
#   ]
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question> > 4:chain:RunnableSequence] [3.15s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question>] [3.15s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 16:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 16:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "Answer the following question based on this context:\n\n[(Document(page_content='# 第２条（給与の形態）  \\n給与の形態は次のとおりです。  \\n基本給  \\n役職手当  \\n通勤手当  \\n時間外労働手当・休日手当・深夜手当  \\n休日振替手当', metadata={'Header 1': '第２条（給与の形態）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.718771403175428), (Document(page_content='# 第４条（役職手当）  \\n## １. 役職手当は、次の金額とします。  \\n部長：50,000円  \\n課長：10,000円', metadata={'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \\n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。', metadata={'Header 1': '第５条（通勤手当）', 'Header 2': '３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='# 第６条（時間外手当・休日手当・深夜手当）  \\n## 時間外手当  \\n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \\n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数', metadata={'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '時間外手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## （退職金の額）  \\n### 第２９条  \\n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。', metadata={'Header 1': '第８章 退職金', 'Header 2': '（退職金の額）', 'Header 3': '第２９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}), 0.2961773305813553), (Document(page_content='## ３. 欠勤の場合は、次の計算により減額します。  \\nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \\n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '３. 欠勤の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553), (Document(page_content='## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553), (Document(page_content='# 第５条（通勤手当）  \\n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。', metadata={'Header 1': '第５条（通勤手当）', 'Header 2': '１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)]\n\nQuestion: 残業手当はいくら？\n",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 17:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Answer the following question based on this context:\n\n[(Document(page_content='# 第２条（給与の形態）  \\n給与の形態は次のとおりです。  \\n基本給  \\n役職手当  \\n通勤手当  \\n時間外労働手当・休日手当・深夜手当  \\n休日振替手当', metadata={'Header 1': '第２条（給与の形態）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.718771403175428), (Document(page_content='# 第４条（役職手当）  \\n## １. 役職手当は、次の金額とします。  \\n部長：50,000円  \\n課長：10,000円', metadata={'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。  \\n（基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。', metadata={'Header 1': '第５条（通勤手当）', 'Header 2': '３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='# 第６条（時間外手当・休日手当・深夜手当）  \\n## 時間外手当  \\n社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。  \\n（基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数', metadata={'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '時間外手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.42259407259407256), (Document(page_content='## （退職金の額）  \\n### 第２９条  \\n退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。', metadata={'Header 1': '第８章 退職金', 'Header 2': '（退職金の額）', 'Header 3': '第２９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}), 0.2961773305813553), (Document(page_content='## ３. 欠勤の場合は、次の計算により減額します。  \\nなお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。  \\n（基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '３. 欠勤の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553), (Document(page_content='## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。', metadata={'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553), (Document(page_content='# 第５条（通勤手当）  \\n## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。', metadata={'Header 1': '第５条（通勤手当）', 'Header 2': '１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}), 0.2961773305813553)]\n\nQuestion: 残業手当はいくら？"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 17:llm:ChatOpenAI] [1.89s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "残業手当は、基本給／１か月の平均所定労働時間数×１．２５×時間外労働時間数により支給されます。",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "残業手当は、基本給／１か月の平均所定労働時間数×１．２５×時間外労働時間数により支給されます。",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 51,
#       "prompt_tokens": 1775,
#       "total_tokens": 1826
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": "fp_69829325d0"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 18:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 18:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "残業手当は、基本給／１か月の平均所定労働時間数×１．２５×時間外労働時間数により支給されます。"
# }
# [chain/end] [1:chain:RunnableSequence] [5.05s] Exiting Chain run with output:
# {
#   "output": "残業手当は、基本給／１か月の平均所定労働時間数×１．２５×時間外労働時間数により支給されます。"
# }
# '残業手当は、基本給／１か月の平均所定労働時間数×１．２５×時間外労働時間数により支給されます。'

# %% [markdown]
# # reference
# https://arxiv.org/abs/2402.03367
#
# https://qiita.com/isanakamishiro2/items/f4387443b86723eecf36
#
# https://github.com/Raudaschl/rag-fusion/blob/master/main.py
