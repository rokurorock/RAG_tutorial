# %% [markdown]
# # Tutorial まずはRAGをやってみる
# 1,LangChainを使ったRAGのチュートリアル

# %% [markdown]
# ## Load Document
# ドキュメントを読み込みます。今回はChatgptで作成した社内文書を模した簡易的なデータセット(company_documents_dataset_1)からフォルダ単位で読み込み

# %%
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("../datasets/company_documents_dataset_1/", glob="**/*.txt",recursive=True)
raw_docs = loader.load()
print("ドキュメントの数:",len(raw_docs))
print(raw_docs[0])
# Out:
# ドキュメントの数: 5
# <class 'langchain_core.documents.base.Document'>
# page_content='# 社宅・寮管理規程\n\n## 第１条（目的）\n\nこの規程は、社員の居住のために会社が所有する社宅または寮および会社名義で借り上げた社宅または寮の管理運営に関する事項を定めたものである。\n\n## 第２条（入居資格）\n\n社宅への入居資格は、配偶者または同居する家族がいる社員とする。\n\n寮への入居資格は、独身者であって自宅から通勤困難な社員とする。\n\n## 第３条（入居への申し込み）\n\n1. 社宅または寮への入居を希望する社員は「社宅・寮入居申込書」に必要事項を記入の上、所属長を経由して漆黒 花太郎へ申し込むものとする。\n\n2. 社宅または寮への入居を許可された社員は、直ちに「社宅・寮入居誓約書」を会社に提出しなければならない。\n\n## 第４条（借上社宅・寮）\n\n社宅または寮への入居希望があるにもかかわらず、入居可能な社宅または寮がない場合は、民間の賃貸住宅を社宅または寮として借り上げることがある。\n\n## 第５条（借上社宅・寮の手配）\n\n借上社宅または寮の手配は会社が行い、家主との間に契約を締結する。\n\n## 第６条（借上社宅の間取り）\n\n借上げ社宅または寮として利用する住宅の間取りは次の区分による。\n\n子がいる場合：３ＤＫ\n\n配偶者のみの場合：２ＤＫ\n\n独身者：１Ｋ\n\n前項の規程に関わらず、扶養家族等の人数により間取りを変更することがある。\n\n## 第７条（借上社宅・寮の家賃限度額）\n\n借上げ社宅または寮の家賃限度額は、次の通りとする。\n\n子がいる場合：100000円\n\n配偶者のみの場合：50000円\n\n独身者：0円\n\n前項の家賃限度額を超過した場合、その超過分については入居者が負担する。\n\n## 第８条（社宅の使用料）\n\n会社所有の社宅または寮の使用料は次の通りとする。\n\n社宅：120000円\n\n寮：80000円\n\n中途入居、中途退去の場合で１か月に満たないときは、日割計算による。\n\n## 第９条（入居資格の喪失）\n\n社宅入居者が次の各号のいずれかに該当した場合は、入居資格を喪失し、会社が定める期日までに社宅から退去するものとする。\n\n1. 退職\n\n2. 会社に無断で定められた入居者以外の者を居住させた場合\n\n3. その他この規程に違反し、会社が社宅に入居させることを妥当でないと認めた場合\n\n入居者は社宅を退去する場合の現状回復の義務を負うものとする。\n\n## 第１０条（禁止事項）\n\n社宅入居者は会社の事前の承諾なくして次の各号に定めることを禁止する。\n\n1. 社宅の転貸をすること\n\n2. 定められた以外の者を同居させること\n\n3. 社宅を他の目的に使用すること\n\n4. 社宅の増改築、模様替え、施設及び敷地の現状を変更すること\n\n## 第１１条（損害賠償）\n\n社宅入居者が故意または過失により、建物を破損または建物の全部若しくは一部を滅失させたときは、入居者の負担により修理修繕し、またはその損害を賠償するものとする。\n\n## 第１２条（施行）\n\nこの規程は令和04年04月12日から施行する' metadata={'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}

# %% [markdown]
# ##  Text Split
# MarkdownHeaderTextSplitter + RecursiveCharacterTextSplitterの二つを使ってテキストを分割。

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter,RecursiveCharacterTextSplitter
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on, 
    return_each_line=False,
    strip_headers = False 
)
docs = []
for raw_doc in raw_docs:
    source = raw_doc.metadata["source"]
    spilited_docs = markdown_splitter.split_text(raw_doc.page_content)
    for doc in spilited_docs:
        doc.metadata["source"] = source#metadataにフォルダのパスを加える
    docs = docs + spilited_docs

markdown_splited_docs = docs
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 300,chunk_overlap=50)
docs = text_splitter.split_documents(docs)
for doc in docs:
    print("【page_content】")
    print(doc.page_content)
    print("【metadata】")
    print(doc.metadata)
    print("-"*180)
print("markdown分割後のドキュメントの数:",len(markdown_splited_docs))
print("RecursiveCharacterTextSplitterで分割後のドキュメントの数:",len(docs))
# Out:
# 【page_content】
# # 社宅・寮管理規程
# ## 第１条（目的）
# この規程は、社員の居住のために会社が所有する社宅または寮および会社名義で借り上げた社宅または寮の管理運営に関する事項を定めたものである。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第１条（目的）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第２条（入居資格）
# 社宅への入居資格は、配偶者または同居する家族がいる社員とする。
# 寮への入居資格は、独身者であって自宅から通勤困難な社員とする。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第２条（入居資格）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第３条（入居への申し込み）
# 1. 社宅または寮への入居を希望する社員は「社宅・寮入居申込書」に必要事項を記入の上、所属長を経由して漆黒 花太郎へ申し込むものとする。
# 2. 社宅または寮への入居を許可された社員は、直ちに「社宅・寮入居誓約書」を会社に提出しなければならない。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第３条（入居への申し込み）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第４条（借上社宅・寮）
# 社宅または寮への入居希望があるにもかかわらず、入居可能な社宅または寮がない場合は、民間の賃貸住宅を社宅または寮として借り上げることがある。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第４条（借上社宅・寮）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第５条（借上社宅・寮の手配）
# 借上社宅または寮の手配は会社が行い、家主との間に契約を締結する。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第５条（借上社宅・寮の手配）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第６条（借上社宅の間取り）
# 借上げ社宅または寮として利用する住宅の間取りは次の区分による。
# 子がいる場合：３ＤＫ
# 配偶者のみの場合：２ＤＫ
# 独身者：１Ｋ
# 前項の規程に関わらず、扶養家族等の人数により間取りを変更することがある。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第６条（借上社宅の間取り）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第７条（借上社宅・寮の家賃限度額）
# 借上げ社宅または寮の家賃限度額は、次の通りとする。
# 子がいる場合：100000円
# 配偶者のみの場合：50000円
# 独身者：0円
# 前項の家賃限度額を超過した場合、その超過分については入居者が負担する。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第７条（借上社宅・寮の家賃限度額）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第８条（社宅の使用料）
# 会社所有の社宅または寮の使用料は次の通りとする。
# 社宅：120000円
# 寮：80000円
# 中途入居、中途退去の場合で１か月に満たないときは、日割計算による。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第８条（社宅の使用料）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第９条（入居資格の喪失）
# 社宅入居者が次の各号のいずれかに該当した場合は、入居資格を喪失し、会社が定める期日までに社宅から退去するものとする。
# 1. 退職
# 2. 会社に無断で定められた入居者以外の者を居住させた場合
# 3. その他この規程に違反し、会社が社宅に入居させることを妥当でないと認めた場合
# 入居者は社宅を退去する場合の現状回復の義務を負うものとする。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第９条（入居資格の喪失）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第１０条（禁止事項）
# 社宅入居者は会社の事前の承諾なくして次の各号に定めることを禁止する。
# 1. 社宅の転貸をすること
# 2. 定められた以外の者を同居させること
# 3. 社宅を他の目的に使用すること
# 4. 社宅の増改築、模様替え、施設及び敷地の現状を変更すること
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第１０条（禁止事項）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第１１条（損害賠償）
# 社宅入居者が故意または過失により、建物を破損または建物の全部若しくは一部を滅失させたときは、入居者の負担により修理修繕し、またはその損害を賠償するものとする。
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第１１条（損害賠償）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 第１２条（施行）
# この規程は令和04年04月12日から施行する
# 【metadata】
# {'Header 1': '社宅・寮管理規程', 'Header 2': '第１２条（施行）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/社宅管理規定.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （目的）
# ### 第１条
# 1. この規則は、世界一のブラック企業株式会社（以下「会社」という）の従業員の労働条件、服務規律その他の就業に関する事項を定めるものである。
# 2. この規則に定めのない事項については、労働基準法その他の法令の定めるところによる。
# 【metadata】
# {'Header 2': '（目的）', 'Header 3': '第１条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （適用範囲）
# ### 第２条
# この規則は、第２章で定める手続きにより採用された従業員に適用する。ただし、契約社員、パートタイマー及び嘱託等の就業に関し必要な事項については、別に定めるそれぞれの就業規則による。
# 【metadata】
# {'Header 2': '（適用範囲）', 'Header 3': '第２条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （規則の遵守）
# ### 第３条
# 会社および社員はこの規則を守り、誠実にその業務を履行して会社の発展に努めなければならない。
# 【metadata】
# {'Header 2': '（規則の遵守）', 'Header 3': '第３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第２章 採用、異動等
# ## （採用手続き）
# ### 第４条
# 会社は、就職希望者のうちから選考して、従業員を採用する。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（採用手続き）', 'Header 3': '第４条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （採用時の提出書類）
# ### 第５条
# 1. 従業員に採用されたときは、２週間以内に、次の書類を提出しなければならない。
# 誓約書
# 住民票記載事項の証明書
# 職歴のある者にあっては、年金手帳及び雇用保険被保険者証
# 免許証その他資格証明書の写
# その他会社が提出を求めた書類
# 2. 前項の提出書類の記載事項に変更を生じたときは、速やかに書面でこれを届け出なければならない。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（採用時の提出書類）', 'Header 3': '第５条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （試用期間）
# ### 第６条
# 1. 新たに採用した者については、採用の日から3ヶ月間を試用期間とする。ただし、会社が適当と認めるときは、この期間を短縮し、又は設けないことがある。
# 2. 試用期間中に従業員として不適格と認められた者は、解雇することがある。
# 3. 試用期間は、勤続年数に通算する。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（試用期間）', 'Header 3': '第６条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （労働条件の明示等）
# ### 第７条
# 1. 会社は、社員の採用に際し、この規則を提示し、労働条件の説明を行い、労働条件を明らかにした書面を交付するものとする。
# 2. 会社は、この規則（附属規定を含む。）及び賃金控除協定書、時間外休日労働に関する協定届、年次有給休暇の計画的付与に関する協定書等の労使協定については、従業員が常時、閲覧することができるように、所定の場所に備え付けておくものとする。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（労働条件の明示等）', 'Header 3': '第７条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （人事異動）
# ### 第８条
# 1. 会社は、業務上必要がある場合または社員の健康状態により、社員に対して就業する場所または従事する業務の変更を命ずることがある。
# 2. 異動を命ずるに当たっては、本人に事前に職場･職務･時期等を伝達し、それに関する意向を聴取して行い、社員は正当な理由なくしてこれを拒むことはできない。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（人事異動）', 'Header 3': '第８条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （休職）
# ### 第９条
# 1. 社員が、次の各号の一に該当する場合は、休職とする。
# 業務外の傷病により欠勤が3ヶ月を超えたとき
# 自己の都合で1ヶ月を超えて欠勤したとき
# 会社の承認を得て、公職に就任し、会社の業務と両立しないとき
# 会社の命令により、会社外の職務に就任したとき
# 刑事事件に関し起訴されたとき
# 全号のほか、特別の事情があり、会社が休職を認めたとき
# 2. 休職期間中に休職事由が消滅した時は、もとの職務に復帰させる。ただし、もとの職務に復帰させることが困難であるか、または不適当な場合には、他の職務につかせることがある。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（休職）', 'Header 3': '第９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 3. 休職期間中の給与は支給しない。
# 4. 休職期間は勤続年数に通算しない。
# 5. 前項第1条により休職し、休職期間が満了してもなお傷病が治癒せず就業が困難な場合は、休職期間の満了をもって退職とする。
# 【metadata】
# {'Header 1': '第２章 採用、異動等', 'Header 2': '（休職）', 'Header 3': '第９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第３章 服務規律
# ## （服務）
# ### 第１０条
# 従業員は、会社の指示命令を守り、職務上の責任を自覚し、誠実に職務を遂行するとともに、職場の秩序の維持に努めなければならない。
# 【metadata】
# {'Header 1': '第３章 服務規律', 'Header 2': '（服務）', 'Header 3': '第１０条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （遵守事項）
# ### 第１１条
# 従業員は、次の事項を守らなければならない。
# 勤務中は職務に専念し、みだりに勤務の場所を離れないこと。
# 許可なく職務以外の目的で会社の施設、物品等を使用しないこと。
# 職務を利用して自己の利益を図らないこと。
# 職務を利用して、他より不当に金品を借用し、贈与を受けるなど不正な行為を行わないこと。
# 会社の名誉又は信用を傷つける行為をしないこと。
# 会社の機密を漏らさないこと。
# 許可なく他の会社等の業務に従事しないこと。
# 性的な言動によって他の従業員に不利益を与えたり、就業環境を害さないこと。
# 【metadata】
# {'Header 1': '第３章 服務規律', 'Header 2': '（遵守事項）', 'Header 3': '第１１条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 性的な言動によって他の従業員に不利益を与えたり、就業環境を害さないこと。
# その他酒気をおびて就業するなど従業員としてふさわしくない行為をしないこと。
# 【metadata】
# {'Header 1': '第３章 服務規律', 'Header 2': '（遵守事項）', 'Header 3': '第１１条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （出退勤）
# ### 第１２条
# 社員は、出退勤にあたっては、次の事項を守らなければならない。
# 出勤および退勤の際は、タイムカードに記録する。
# 始業時刻前に出勤し、始業時刻に勤務が開始できるように準備する。
# 【metadata】
# {'Header 1': '第３章 服務規律', 'Header 2': '（出退勤）', 'Header 3': '第１２条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （遅刻、早退、欠勤等）
# ### 第１３条
# 1. 従業員が、遅刻、早退若しくは欠勤をし、又は勤務時間中に私用外出するときは、事前に申し出て許可を受けなければならない。ただし、やむを得ない理由で事前に申し出ることができなかった場合は、事後に速やかに届け出なければならない。
# 2. 傷病のため欠勤が引き続き○
# 日以上に及ぶときは、医師の診断書を提出しなければならない。
# 【metadata】
# {'Header 1': '第３章 服務規律', 'Header 2': '（遅刻、早退、欠勤等）', 'Header 3': '第１３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第４章 労働時間、休憩及び休日
# ## （労働時間及び休憩時間）
# ### 第１４条
# 1. １週間の所定労働時間は、60時間以内とする。
# 2. １日の所定労働時間は、10時間とする。
# 3. 始業時刻・終業時刻および休憩時間は、次のとおりとする。
# 始業時刻：午前
# 時○
# 分
# 終業時刻：午後
# 時○
# 分
# 休憩時間：○
# 時から
# 時間
# 4. 従業員は、休憩時間を自由に利用することができる。ただし、休憩時間中に遠方に外出するときは、所属長に届け出るものとする。
# 【metadata】
# {'Header 1': '第４章 労働時間、休憩及び休日', 'Header 2': '（労働時間及び休憩時間）', 'Header 3': '第１４条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （休日）
# ### 第１５条
# 1. 休日は、次のとおりとする。
# 土曜日及び日曜日
# 国民の祝日・休日
# 年末年始
# 夏季休日
# その他会社が指定する日
# 2. 業務の都合により会社が必要と認める場合は、あらかじめ前項の休日を他の日と振り替えることがある。
# 【metadata】
# {'Header 1': '第４章 労働時間、休憩及び休日', 'Header 2': '（休日）', 'Header 3': '第１５条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （時間外及び休日労働）
# ### 第１６条
# 1. 業務の都合により、所定時間外に就業させたり、第１５条に定める休日に勤務させることがある。
# 2. 育児や介護を行う女子が会社に申し出た場合に限り、時間外勤務は１週間に６時間、1年に１５０時間を越えない範囲とする。
# 3. 申し出た妊娠中の女性及び産後１年を経過しない女性と１８歳未満の社員には時間外労働、休日労働及び深夜業に従事させない。
# 4. 小学校就学前の子の養育又は家族の介護を行う一定範囲の従業員で会社に請求した者については、事業の正常な運営を妨げる場合を除き、深夜業に従事させない。
# 【metadata】
# {'Header 1': '第４章 労働時間、休憩及び休日', 'Header 2': '（時間外及び休日労働）', 'Header 3': '第１６条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 5. 前項の深夜業の制限の手続等必要な事項については、「育児休業、介護休業等に関する規定」に定めるところによる。
# 【metadata】
# {'Header 1': '第４章 労働時間、休憩及び休日', 'Header 2': '（時間外及び休日労働）', 'Header 3': '第１６条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第５章 休暇等
# ## （年次有給休暇）
# ### 第１７条
# 1. 会社は、６ヶ月間継続勤務し、所定就業日数の８割以上勤務した社員には、１０日の年次有給休暇を与える。
# 2. 1年６ヶ月以上継続勤務社員に対しては、前年の出勤率が８割以上の場合、次の表のとおり年次有給休暇を与える。ただし、２０日を上限とする。
# 3. 年次有給休暇を受ける場合は、その前日までに所属長に書面をもって届け出るものとする。本人の急病等真にやむを得ない事情がある場合を除き、当日の休暇の申し出は認めない。
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（年次有給休暇）', 'Header 3': '第１７条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （産前産後の休業）
# ### 第１８条
# 1. ６週間（多胎妊娠の場合は１４週間）以内に出産する予定の女性従業員から請求があったときは、休業させる。
# 2. 出産した女性従業員は、８週間は休業させる。ただし、産後６週間を経過した女性従業員から請求があったときは、医師が支障がないと認めた業務に就かせることができる。
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（産前産後の休業）', 'Header 3': '第１８条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （育児時間及び生理休暇）
# ### 第１９条
# 1. 満１歳に達しない生児を育てる女性従業員は、第１４条の休憩時間のほか、１日２回、各々３０分の育児時間を請求することができる。
# 2. 生理日の就業が著しく困難な女性従業員が請求した場合には、生理休暇を与える。
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（育児時間及び生理休暇）', 'Header 3': '第１９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （育児休業）
# ### 第２０条
# この制度の適用を受けることができる従業員の範囲やその他必要な事項については、別途「育児休業、介護休業等に関する規定」に定めるところによる。
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（育児休業）', 'Header 3': '第２０条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （介護休業）
# ### 第２１条
# この制度の適用を受けることができる従業員の範囲やその他必要な事項については、別途「育児休業、介護休業等に関する規定」に定めるところによる。
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（介護休業）', 'Header 3': '第２１条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （慶弔休暇）
# ### 第２２条
# 従業員が次の事由により休暇を申請した場合は、次のとおり慶弔休暇を与える。
# 本人が結婚したとき：1日
# 妻が出産したとき：2日
# 配偶者、子又は父母が死亡したとき：3日
# 兄弟姉妹、祖父母、配偶者の父母又は兄弟姉妹が死亡したとき：4日
# その他前各号に準じ会社が認めたとき：必要と認める期間
# 【metadata】
# {'Header 1': '第５章 休暇等', 'Header 2': '（慶弔休暇）', 'Header 3': '第２２条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第６章 給与等
# ## （給与）
# ### 第２３条
# 社員に対する給与および昇給などに関する事項および賞与に関する事項は、別に定める「給与規程」による。
# 【metadata】
# {'Header 1': '第６章 給与等', 'Header 2': '（給与）', 'Header 3': '第２３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （賞与）
# ### 第２４条
# 1. 賞与は、原則として毎年2月20日及び6月20日に在籍する従業員に対し、会社の業績等を勘案して3月30日及び7月30日に支給する。ただし、会社の業績の著しい低下その他やむを得ない事由がある場合には、支給時期を延期し、又は支給しないことがある。
# 2. 前項の賞与の額は、会社の業績及び従業員の勤務成績などを考慮して各人ごとに決定する。
# 【metadata】
# {'Header 1': '第６章 給与等', 'Header 2': '（賞与）', 'Header 3': '第２４条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第７章 定年、退職及び解雇
# ## （定年等）
# ### 第２５条
# 1. 従業員（契約社員、嘱託、パートタイマーを除く）の定年は、満○
# 歳とし、定年に達した日の属する月の末日をもって退職とする。
# 2. 定年に達した従業員について、本人の希望により一定の期間引き続き雇用することがある。
# 【metadata】
# {'Header 1': '第７章 定年、退職及び解雇', 'Header 2': '（定年等）', 'Header 3': '第２５条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （退職）
# ### 第２６条
# 1. 前条に定めるもののほか従業員が次のいずれかに該当するときは、退職とする。
# 退職を願い出て会社から承認されたとき、又は退職願を提出して14日を経過したとき
# 期間を定めて雇用されている場合、その期間を満了したとき
# 第９条に定める休職期間が満了し、なお、休職事由が消滅しないとき
# 第２５条の定年に達したとき
# 死亡したとき
# 2. 従業員が、退職の場合において、退職の事由（解雇の場合はその事由を含む。）等について証明書を請求した場合は、会社は遅滞なく交付するものとする。
# 【metadata】
# {'Header 1': '第７章 定年、退職及び解雇', 'Header 2': '（退職）', 'Header 3': '第２６条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （解雇）
# ### 第２７条
# 1. 従業員が次のいずれかに該当するときは、解雇するものとする。
# 勤務成績又は業務能率が著しく不良で、従業員としてふさわしくないと認められたとき。ただし、第３３条第２項の事由に該当すると認められたときは、同条の定めるところによる。
# 精神又は身体の障害により、業務に耐えられないと認められたとき
# 事業の縮小その他事業の運営上やむを得ない事情により、従業員の減員等が必要となったとき
# その他前各号に準ずるやむを得ない事情があるとき
# 【metadata】
# {'Header 1': '第７章 定年、退職及び解雇', 'Header 2': '（解雇）', 'Header 3': '第２７条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# その他前各号に準ずるやむを得ない事情があるとき
# 2. （解雇の予告）前項の規定により従業員を解雇する場合は、少なくとも30日前に予告をするか、又は平均賃金の30日分以上の解雇予告手当を支払う。なお、解雇予告日数は、平均賃金を支払った日数だけ短縮することができるものとする。
# ただし、所轄労働基準監督署長の認定を受けて解雇をする場合、及び次のいずれかに該当する従業員を解雇する場合は、この限りでない。
# 日々雇い入れられる従業員（1か月を超えて引き続き雇用された者を除く）
# 2か月以内の期間を定めて使用する従業員（その期間を超えて引き続き雇用された者を除く）
# 【metadata】
# {'Header 1': '第７章 定年、退職及び解雇', 'Header 2': '（解雇）', 'Header 3': '第２７条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 2か月以内の期間を定めて使用する従業員（その期間を超えて引き続き雇用された者を除く）
# 試用期間中の従業員（14日を超えて引き続き雇用された者を除く）
# 【metadata】
# {'Header 1': '第７章 定年、退職及び解雇', 'Header 2': '（解雇）', 'Header 3': '第２７条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第８章 退職金
# ## （退職金の支給）
# ### 第２８条
# 勤続30年以上の従業員が退職し又は解雇されたときは、退職金を支給する。ただし、第４６条第２項により懲戒解雇された者には、退職金の全部又は一部を支給しないことがある。
# 【metadata】
# {'Header 1': '第８章 退職金', 'Header 2': '（退職金の支給）', 'Header 3': '第２８条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （退職金の額）
# ### 第２９条
# 退職金の額は、一律4000000円です。退職金に関する詳細は「退職金規定」を参考にしてください。
# 【metadata】
# {'Header 1': '第８章 退職金', 'Header 2': '（退職金の額）', 'Header 3': '第２９条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （退職金の支払方法及び支払時期）
# ### 第３０条
# 退職金は、支給の事由の生じた日から1か月以内に、退職した従業員（死亡による退職の場合はその遺族）に対して支払う。
# 【metadata】
# {'Header 1': '第８章 退職金', 'Header 2': '（退職金の支払方法及び支払時期）', 'Header 3': '第３０条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第９章 表彰及び懲戒
# ## （表彰）
# ### 第３１条
# 会社は、従業員が次のいずれかに該当する場合は、表彰する。
# 業務上有益な創意工夫、改善を行い、会社の運営に貢献したとき
# 永年にわたって誠実に勤務し、その成績が優秀で他の模範となるとき
# 事故、災害等を未然に防ぎ、又は非常事態に際し適切に対応し、被害を最小限にとどめるなど特に功労があったとき
# 社会的功績があり、会社及び従業員の名誉となったとき
# 前各号に準ずる善行又は功労のあったとき
# 【metadata】
# {'Header 1': '第９章 表彰及び懲戒', 'Header 2': '（表彰）', 'Header 3': '第３１条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （懲戒の種類）
# ### 第３２条
# 懲戒は、その情状に応じ、次の区分により行う。
# けん責：始末書を提出させて将来を戒める。
# 減給：１回の事案に対する額が、平均賃金の１日分の半額、総額が当該月の賃金総額の１０分に１の範囲内で行う。
# 出勤停止：７日間を限度として出勤を停止し、その間の賃金は支給しない。
# 解雇：解雇に当たっては、第２７条第２項の手続による。
# 懲戒解雇：退職金の全部又は一部を支払わないで解雇する。この場合において所轄労働基準監督署長の認定を受けたときは解雇予告手当を支給せず、即時に解雇する。
# 【metadata】
# {'Header 1': '第９章 表彰及び懲戒', 'Header 2': '（懲戒の種類）', 'Header 3': '第３２条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （懲戒の事由）
# ### 第３３条
# 1. 従業員が次のいずれかに該当するときは、情状に応じ、けん責、減給又は出勤停止とする。
# 正当な理由なく無断欠勤5日以上に及ぶとき
# 正当な理由なくしばしば欠勤、遅刻、早退するなど勤務を怠ったとき
# 過失により、業務上の事故又は災害を発生させ、会社に重大な損害を与えたとき
# 素行不良やセクシャル・ハラスメントの問題で会社内の秩序又は風紀を乱したとき
# 第１１条の規定に違反する行為があったとき
# その他この規則に違反し、又は前各号に準ずる不都合な行為があったとき
# 【metadata】
# {'Header 1': '第９章 表彰及び懲戒', 'Header 2': '（懲戒の事由）', 'Header 3': '第３３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# その他この規則に違反し、又は前各号に準ずる不都合な行為があったとき
# 2. 従業員が、次のいずれかに該当するときは、懲戒解雇とする。ただし、情状により通常の解雇又は減給もしくは出勤停止とすることがある。
# 正当な理由なく、無断欠勤14日以上に及び、出勤の督促に応じないとき
# しばしば遅刻、早退及び欠勤を繰り返し、そのため会社の業務運営に著しい支障を与え、上司が数回にわたって注意を与えても改善の見込みがないとき
# 会社内における窃盗、横領、傷害等刑法犯に該当する行為があったとき、又はこれらの行為が会社外で行われた場合であっても、それが著しく会社の名誉若しくは信用を傷つけたとき
# 【metadata】
# {'Header 1': '第９章 表彰及び懲戒', 'Header 2': '（懲戒の事由）', 'Header 3': '第３３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 故意又は重過失により、業務上の事故若しくは災害を発生させ、会社に重大な損害を与えたとき
# 素行不良やセクシャル・ハラスメントの問題で会社内の秩序又は風紀を著しく乱したとき
# 重大な経歴を偽り採用されたとき
# 第１１条の規定に違反する極めて重大な行為があったとき
# その他前各号に準ずる重大な行為があったとき
# 【metadata】
# {'Header 1': '第９章 表彰及び懲戒', 'Header 2': '（懲戒の事由）', 'Header 3': '第３３条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第１０章 安全衛生及び災害補償等
# ## （安全衛生の基本的事項）
# ### 第３４条
# 1. 会社は、従業員の安全確保と健康の保持増進を図り、快適な職場の形成のため必要な措置を講ずる。
# 2. 会社は、法令の定めるところにより、職場の安全衛生管理に当たらせるために、必要な管理者の選任を行う。
# 3. 従業員は、次の事項を守るほか、その他、職場の安全衛生のために会社が行う指示を遵守しなければならない。
# 火気、電気、水道、ガス等を使用した者は、その後始末を確認すること。
# 喫煙は所定の場所以外で行わないこと。
# 通路、避難口に物品を置かないこと。
# 【metadata】
# {'Header 1': '第１０章 安全衛生及び災害補償等', 'Header 2': '（安全衛生の基本的事項）', 'Header 3': '第３４条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 喫煙は所定の場所以外で行わないこと。
# 通路、避難口に物品を置かないこと。
# 立入禁止、通行禁止区域には立ち入らないこと。
# 服装は業務に適したものとすること。
# 事故発生の場合の緊急連絡及び応急措置について熟知しておくこと。
# 資格を要する業務に無資格で従事しないこと。
# 会社が行う安全衛生教育で教わった事項を実行すること。
# 4. 会社は、法令の定めるところによるほか、必要に応じて従業員に対する安全衛生教育を行う。
# 5. 会社は、安全衛生管理のために必要と認める場合、別に「安全衛生管理規定」を定めることがある。
# 【metadata】
# {'Header 1': '第１０章 安全衛生及び災害補償等', 'Header 2': '（安全衛生の基本的事項）', 'Header 3': '第３４条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （健康診断）
# ### 第３５条
# 1. 従業員に対しては、採用時及び毎年1回（深夜労働その他労働安全衛生規則第13条第1項第2号の定める業務に従事する者は6ヶ月ごとに1回）、定期健康診断を行う。なお、健康診断の結果については、各従業員に通知する。
# 2. 前項の健康診断のほか、法令で定められた有害業務に従事する従業員に対しては、特別の項目について健康診断を行う。
# 3. 従業員は、会社が行う健康診断を拒んではならない。ただし、他の医師の健康診断を受け、その結果を証明する書類を提出した場合は、この限りでない。
# 【metadata】
# {'Header 1': '第１０章 安全衛生及び災害補償等', 'Header 2': '（健康診断）', 'Header 3': '第３５条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 4. 第1項及び第2項の健康診断の結果必要を認めるときは、就業時間の短縮、配置転換その他健康確保上の必要な措置を命ずることがある。
# 【metadata】
# {'Header 1': '第１０章 安全衛生及び災害補償等', 'Header 2': '（健康診断）', 'Header 3': '第３５条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## （災害補償等）
# ### 第３６条
# 1. 業務上の事由又は通勤により負傷し、疾病にかかり、又は死亡した場合は、労災保険法に定めるところにより災害補償を行う。
# 2. 従業員が、業務外の事由により傷病にかかり労務に服することができないときは、健康保険法により給付を受けるものとする。
# 【metadata】
# {'Header 1': '第１０章 安全衛生及び災害補償等', 'Header 2': '（災害補償等）', 'Header 3': '第３６条', 'source': '../datasets/company_documents_dataset_1/規定及び規則/就業規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第１条（総則）
# この規則は就業規則第条の社員の給与について定めた規則です。
# 【metadata】
# {'Header 1': '第１条（総則）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第２条（給与の形態）
# 給与の形態は次のとおりです。
# 基本給
# 役職手当
# 通勤手当
# 時間外労働手当・休日手当・深夜手当
# 休日振替手当
# 【metadata】
# {'Header 1': '第２条（給与の形態）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第３条（基本給）
# 基本給は、本人の年齢、学歴、経験、技能等を総合的に勘案し、各人別に月額をもって決定します。
# 【metadata】
# {'Header 1': '第３条（基本給）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第４条（役職手当）
# ## １. 役職手当は、次の金額とします。
# 部長：50,000円
# 課長：10,000円
# 【metadata】
# {'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ２. 役職手当は支給対象となった翌月分から支払います。
# ただし、給与計算期間の初日に支給対象となった場合は当月分から支払います。
# 【metadata】
# {'Header 1': '第４条（役職手当）', 'Header 2': '２. 役職手当は支給対象となった翌月分から支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ３. 役職手当は、支給対象外となった翌月分から支払わないこととします。
# ただし、給与計算期間の初日に支給対象外となった場合は当月分から支払ないこととします。
# 【metadata】
# {'Header 1': '第４条（役職手当）', 'Header 2': '３. 役職手当は、支給対象外となった翌月分から支払わないこととします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第５条（通勤手当）
# ## １. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。
# 【metadata】
# {'Header 1': '第５条（通勤手当）', 'Header 2': '１. 通勤手当は会社が認めた通勤経路に基づく、１か月分の交通機関の定期代相当を支給します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ２. 給与計算期間途中で、通勤経路変更等で金額変更になった場合は、給与支払日を待たず速やかに精算処理します。
# 変更後の通勤手当は翌月分から支払います。
# 【metadata】
# {'Header 1': '第５条（通勤手当）', 'Header 2': '２. 給与計算期間途中で、通勤経路変更等で金額変更になった場合は、給与支払日を待たず速やかに精算処理します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。
# 【metadata】
# {'Header 1': '第５条（通勤手当）', 'Header 2': '３. 給与計算期間を、すべて欠勤または無給休暇した場合、通勤手当は支給しない。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第６条（時間外手当・休日手当・深夜手当）
# ## 時間外手当
# 社員に、所定労働時間を超えて労働をさせたときは、次の計算により時間外手当を支払います。
# （基本給／１か月の平均所定労働時間数）×１．２５×時間外労働時間数
# 【metadata】
# {'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '時間外手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 休日手当
# 社員に、会社の休日に労働させたときは次の計算により手当を支払います。
# （基本給／１か月の平均所定労働時間数）×１．３５×休日労働時間数
# 【metadata】
# {'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '休日手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 深夜手当
# 社員に、午後１０時から翌日の午前５時までの間に労働させたときは、次の計算により手当を支払います。
# （基本給／１か月の平均所定労働時間数）×１．２５×深夜労働時間数
# 【metadata】
# {'Header 1': '第６条（時間外手当・休日手当・深夜手当）', 'Header 2': '深夜手当', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第７条（休日振替手当）
# 休日の振替を行った場合は１回につき次の手当を支給します。
# １回：1,000円
# 【metadata】
# {'Header 1': '第７条（休日振替手当）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第８条（給与の計算期間・支払日）
# ## １. 給与は、毎月２０日に締切り毎月末日に支払います。
# ただし、支払日が会社の休日（金融機関の休日含む）に当たる場合は、前日に支払います。
# 【metadata】
# {'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '１. 給与は、毎月２０日に締切り毎月末日に支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。
# （基本給＋役職手当）×（給与計算期間の実労働日数／給与計算期間の所定労働日数）
# 【metadata】
# {'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '２. 給与計算期間の途中で入社・退職・解雇等の場合は次の日割計算により支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ３. 欠勤の場合は、次の計算により減額します。
# なお、給与計算期間すべて欠勤した場合、基本給・役職手当は支給しない。
# （基本給＋役職手当）×（給与計算期間の欠勤日数／給与計算期間の所定労働日数）
# 【metadata】
# {'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '３. 欠勤の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。
# なお、給与計算期間すべて無給休暇の場合、基本給・役職手当は支給しない。
# (基本給＋役職手当)×（給与計算期間の無給休暇日数／給与計算期間の所定労働日数）
# 【metadata】
# {'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '４. 給与計算期間途中での無給休暇の場合は、次の計算により減額します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。
# 【metadata】
# {'Header 1': '第８条（給与の計算期間・支払日）', 'Header 2': '５. 給与計算期間における時間外労働・休日労働・深夜労働の各時間数の集計については、３０分未満は切捨て、３０分以上は１時間に切上げます。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第９条（給与の支払方法、控除方法）
# ## １. 給与は通貨で直接社員に全額支払います。
# ただし、社員代表と労使協定を締結し、社員の同意を得た場合は、社員の指定する社員本人名義の銀行口座は振り込むことにより支払います。
# 【metadata】
# {'Header 1': '第９条（給与の支払方法、控除方法）', 'Header 2': '１. 給与は通貨で直接社員に全額支払います。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## ２. 次については給与から控除します。
# 健康保険料
# 厚生年金保険料
# 雇用保険料
# 源泉所得税
# 市町村民税
# 社員代表との労使協定により給与から控除することとしたもの
# 【metadata】
# {'Header 1': '第９条（給与の支払方法、控除方法）', 'Header 2': '２. 次については給与から控除します。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 第10条（昇給）
# 昇給は原則行いません。ただし、各人の勤務成績等により、特別に必要があると場合は臨時に昇給を行う場合があります。
# 【metadata】
# {'Header 1': '第10条（昇給）', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # 株式会社架空ブラック 会社情報
# ## 会社概要
# ### 名称
# 株式会社架空ブラック
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '名称', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 設立
# 2021年
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '設立', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 所在地
# 東京都中央区架空町1ー1ー1
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '所在地', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 資本金
# 5,000万円
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '資本金', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 従業員数
# 約50名
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '従業員数', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 売上高
# 約10億円（2023年度予測）
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '売上高', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 事業内容
# 高品質なマッサージチェアの開発・販売
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '事業内容', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 社長
# 漆黒 花太郎（しっこく かたろう）
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '社長', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 社長のプロフィール
# ### 名前
# 漆黒 花太郎（しっこく かたろう）
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '名前', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 生年月日
# 1975年4月1日
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '生年月日', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 出身地
# 福岡県
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '出身地', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 学歴
# 東京大学大学院 情報理工学研究科 修了
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '学歴', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### 経歴
# 2000年:大手IT企業に入社、システムエンジニアとしてキャリアをスタート
# 2010年:マーケティング部門に異動、デジタルマーケティング戦略を担当
# 2018年:同社を退社し、独立準備のための事業を開始
# 2021年:株式会社架空ブラックを設立、代表取締役に就任。マッサージチェアの開発・販売を事業の中心に据える
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '経歴', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 企業理念
# ### ミッション
# 「至福のリラクゼーションを提供する」をミッションに、革新的なマッサージチェアを通じて、人々の健康と幸福を支援します。
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '企業理念', 'Header 3': 'ミッション', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### ビジョン
# 世界中のすべての家庭やオフィスに、最高品質のリラクゼーション体験を提供することで、より健康で幸せな生活を実現する社会の実現を目指します。
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '企業理念', 'Header 3': 'ビジョン', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### バリュー
# 顧客第一:顧客の満足と健康を最優先に考え、製品開発からサービス提供まで全てのプロセスで顧客中心の姿勢を貫きます。
# 品質追求:技術革新を続け、常に業界最高水準の品質を目指します。
# オープンイノベーション:外部のアイデアや技術も取り入れながら、より良い製品の開発を目指します。
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '企業理念', 'Header 3': 'バリュー', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 連絡先
# ### 電話番号
# 0312345678
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '連絡先', 'Header 3': '電話番号', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### メールアドレス
# info@kakuoblack.co.jp
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '連絡先', 'Header 3': 'メールアドレス', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ### ウェブサイト
# http://www.kakuoblack.co.jp
# 以上が、株式会社架空ブラックの会社情報です。私たちは、革新的なマッサージチェアを通じて、人々の健康と幸福に貢献することを目指しています。
# 【metadata】
# {'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '連絡先', 'Header 3': 'ウェブサイト', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# # リモートワークマニュアル
# 株式会社 架空ブラック
# リモートワークを効率的かつ円滑に行うためのガイドラインをまとめました。注意点、会議の手順、出勤・退勤の方法について説明します。
# 【metadata】
# {'Header 1': 'リモートワークマニュアル', 'source': '../datasets/company_documents_dataset_1/マニュアル/リモートワークガイドライン.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 注意点
# 1. *
# 作業環境の整備：*
# 静かで快適な作業スペースを確保してください。必要な機材や文房具は事前に準備しておきます。
# 2. *
# セキュリティの確保：*
# 会社から支給されたVPNを通じて業務にアクセスし、個人情報や機密情報の取り扱いには最大限の注意を払ってください。
# 3. *
# 定期的なコミュニケーション：*
# チームメンバーや上司との定期的な連絡を心がけ、進捗状況や問題点を共有します。
# 【metadata】
# {'Header 1': 'リモートワークマニュアル', 'Header 2': '注意点', 'source': '../datasets/company_documents_dataset_1/マニュアル/リモートワークガイドライン.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 会議の手順
# 1. *
# 会議のスケジュール調整：*
# Google Calendarなどを用いて、参加者全員が参加可能な時間を見つけます。
# 2. *
# 会議の準備：*
# 会議資料は事前に共有し、議題については明確にしておきます。
# 3. *
# オンライン会議ツールの使用：*
# ZoomやMicrosoft Teamsなどのオンライン会議ツールを使用します。会議の15分前にはログインし、機材の動作確認を行います。
# 4. *
# 会議の進行：*
# 開始時間になったら、司会者が会議を開始します。発言は手を挙げるなどして順番に行い、混乱を避けます。
# 5. *
# 【metadata】
# {'Header 1': 'リモートワークマニュアル', 'Header 2': '会議の手順', 'source': '../datasets/company_documents_dataset_1/マニュアル/リモートワークガイドライン.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# 5. *
# 会議の記録：*
# 会議の内容は記録し、後日参加者に共有します。
# 【metadata】
# {'Header 1': 'リモートワークマニュアル', 'Header 2': '会議の手順', 'source': '../datasets/company_documents_dataset_1/マニュアル/リモートワークガイドライン.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 【page_content】
# ## 出勤・退勤の方法
# 1. *
# 出勤の記録：*
# 毎朝、指定されたシステムにログインし、出勤の打刻を行います。ログイン時刻が出勤時刻として記録されます。
# 2. *
# 業務の開始：*
# 出勤打刻後、業務に必要なツールやシステムにアクセスし、業務を開始します。
# 3. *
# 退勤の記録：*
# 業務終了時には、再度システムにアクセスし、退勤の打刻を行います。ログアウト時刻が退勤時刻として記録されます。
# このマニュアルは、株式会社架空ブラックの従業員がリモートワークを行う際の基本的なガイドラインです。各自の責任のもと、効率的なリモートワークを実施してください。
# 【metadata】
# {'Header 1': 'リモートワークマニュアル', 'Header 2': '出勤・退勤の方法', 'source': '../datasets/company_documents_dataset_1/マニュアル/リモートワークガイドライン.txt'}
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# markdown分割後のドキュメントの数: 92
# RecursiveCharacterTextSplitterで分割後のドキュメントの数: 102

# %% [markdown]
# ## Embedding

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
vectorstore = Chroma.from_documents(persist_directory="./vecstore/index", documents=docs, embedding=OpenAIEmbeddings())
# Out:
# /Users/rokuroyamaki/anaconda3/envs/llm/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %% [markdown]
# ## similarity_search
# ちゃんとベクトル検索ができるか確認

# %%
question = "社長の名前"
vectorstore = Chroma(persist_directory="./vecstore/index", embedding_function=OpenAIEmbeddings()) #vectorstoreを読み込み
result_docs = vectorstore.similarity_search(question,k=3)
for doc  in  result_docs:
    print(doc)
# Out:
# page_content='### 社長  \n漆黒 花太郎（しっこく かたろう）' metadata={'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '社長', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# page_content='## 社長のプロフィール  \n### 名前  \n漆黒 花太郎（しっこく かたろう）' metadata={'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '名前', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
# page_content='# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円' metadata={'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}

# %% [markdown]
# ## Search and Generate
# ドキュメントを検索して、そのドキュメントをもとにChatGPT3.５で回答します

# %%
from langchain.retrievers import RePhraseQueryRetriever
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.callbacks import get_openai_callback
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA

question = "社長の名前は？"

prompt = PromptTemplate(
    input_variables=["context","question"],
    template="""以下の参考用のテキストの一部を参照して、Questionに回答してください。もし参考用のテキストの中に回答に役立つ情報が含まれていなければ、分からない、と答えてください。
{context}
Question: {question}
Answer: """
)
llm = ChatOpenAI(model_name="gpt-3.5-turbo",temperature=0)
llm_chain = LLMChain(llm=llm, prompt=prompt)
vectorstore = Chroma(persist_directory="./vecstore/index", embedding_function=OpenAIEmbeddings())
retriever = vectorstore.as_retriever(search_kwargs={"k": 4})
qa_chain = RetrievalQA.from_chain_type(llm,retriever=retriever,
                                           chain_type="stuff", 
                                           return_source_documents=True,
                                           verbose=True,
                                           chain_type_kwargs={"prompt":prompt})
with get_openai_callback() as cb:
    result = qa_chain({"query": question})
    print("【質問】:",result["query"],"  【回答】:",result["result"])
    print("")
    print("【回答に使用したドキュメント】")
    if result.get('source_documents'):
        for source  in result['source_documents']:
            print(source)
            print("")
    print("【トークン数】")
    print(cb)
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
# 【質問】: 社長の名前は？   【回答】: 漆黒 花太郎（しっこく かたろう）
#
# 【回答に使用したドキュメント】
# page_content='### 社長  \n漆黒 花太郎（しっこく かたろう）' metadata={'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '社長', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
#
# page_content='## 社長のプロフィール  \n### 名前  \n漆黒 花太郎（しっこく かたろう）' metadata={'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '社長のプロフィール', 'Header 3': '名前', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
#
# page_content='# 第４条（役職手当）  \n## １. 役職手当は、次の金額とします。  \n部長：50,000円  \n課長：10,000円' metadata={'Header 1': '第４条（役職手当）', 'Header 2': '１. 役職手当は、次の金額とします。', 'source': '../datasets/company_documents_dataset_1/規定及び規則/給与規則.txt'}
#
# page_content='### 従業員数  \n約50名' metadata={'Header 1': '株式会社架空ブラック 会社情報', 'Header 2': '会社概要', 'Header 3': '従業員数', 'source': '../datasets/company_documents_dataset_1/マニュアル/会社情報.txt'}
#
# 【トークン数】
# Tokens Used: 247
# 	Prompt Tokens: 225
# 	Completion Tokens: 22
# Successful Requests: 1
# Total Cost (USD): $0.0003815
